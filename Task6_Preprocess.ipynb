# %%
import pandas as pd

# Load the datasets
combined_data = pd.read_csv('https://raw.githubusercontent.com/Cropdata5320/CropData_Visualizations/main/CropYield_Weather_Prices_combined.csv')

# Since we need to group by 'State Name' and 'Year' and calculate the average of certain columns,
# we perform the following groupby operation
grouped = combined_data.groupby(['State Name', 'Year']).agg({
    'yield': 'mean',
    'Avg_Annual_Temperature': 'mean',
    'Avg_Annual_Rainfall': 'mean',
    'average_price': 'mean'
}).reset_index()

grouped
# Out:
#          State Name  Year        yield  Avg_Annual_Temperature  \
# 0    Andhra Pradesh  1994  1204.100909                   24.46
# 1    Andhra Pradesh  1995  1221.896818                   25.29
# 2    Andhra Pradesh  1996  1319.398636                   24.55
# 3    Andhra Pradesh  1997  1153.122273                   24.10
# 4    Andhra Pradesh  1998  1329.869091                   24.76
# ..              ...   ...          ...                     ...
# 473     West Bengal  2013  2596.332222                   24.82
# 474     West Bengal  2014  2655.232667                   24.73
# 475     West Bengal  2015  2313.132667                   24.91
# 476     West Bengal  2016  2526.913556                   25.15
# 477     West Bengal  2017  2646.239778                   24.79
#
#      Avg_Annual_Rainfall  average_price
# 0                 1295.3       6.919554
# 1                 1242.4       7.033452
# 2                 1182.9       8.187600
# 3                 1183.1       8.944368
# ...

# %%
# Save the DataFrame to a new CSV file
grouped.to_csv('Task6_ProcessedData.csv', index=False)
